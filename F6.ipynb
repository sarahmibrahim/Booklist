# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahmibrahim/Booklist/blob/master/F6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using Pandas pt2

# %%
import pandas as pd

# %%
sales_data = pd.read_csv('/content/drive/MyDrive/Sales_Orders GSQ.csv')
sales_data
# Out:
#              Order ID  Order Date  Year  GDSOrder Date        Customer Name  \
# 0     BN-2011-7407039  01/01/2011  2011         112011           Ruby Patel
# 1     AZ-2011-9050313  01/03/2011  2011         132011       Summer Hayward
# 2     AZ-2011-6674300  01/04/2011  2011         142011     Devin Huddleston
# 3     BN-2011-2819714  01/04/2011  2011         142011          Mary Parker
# 4      AZ-2011-617423  01/05/2011  2011         152011         Daniel Burke
# ...               ...         ...   ...            ...                  ...
# 4112  AZ-2014-8174835  12/31/2014  2014       12312014         Eloise Sykes
# 4113   AZ-2014-766953  12/31/2014  2014       12312014         Jose Gambino
# 4114  AZ-2014-1412225  12/31/2014  2014       12312014          Leon Barnes
# 4115  AZ-2014-7604524  12/31/2014  2014       12312014  Rebecca Chamberlain
# 4116  BN-2014-4140795  12/31/2014  2014       12312014      Daniel Hamilton
#
# ...

# %%
#remove column
sales_data.drop(columns='GDSOrder Date', inplace=True)
sales_data
# Out:
#              Order ID  Order Date  Year        Customer Name        City  \
# 0     BN-2011-7407039  01/01/2011  2011           Ruby Patel   Stockholm
# 1     AZ-2011-9050313  01/03/2011  2011       Summer Hayward   Southport
# 2     AZ-2011-6674300  01/04/2011  2011     Devin Huddleston     Valence
# 3     BN-2011-2819714  01/04/2011  2011          Mary Parker  Birmingham
# 4      AZ-2011-617423  01/05/2011  2011         Daniel Burke  EchirolleS
# ...               ...         ...   ...                  ...         ...
# 4112  AZ-2014-8174835  12/31/2014  2014         Eloise Sykes   Bielefeld
# 4113   AZ-2014-766953  12/31/2014  2014         Jose Gambino  Maidenhead
# 4114  AZ-2014-1412225  12/31/2014  2014          Leon Barnes   Worcester
# 4115  AZ-2014-7604524  12/31/2014  2014  Rebecca Chamberlain     Hamburg
# 4116  BN-2014-4140795  12/31/2014  2014      Daniel Hamilton   Eindhoven
#
#                        State         Country   Region      Segment     Sale  \
# ...

# %%
#check for missing values
sales_data['Region'].isnull().sum()
# Out:
# 0

# %%
sales_data['Country'].isnull().sum()
# Out:
# 0

# %%
#return a list of unique values in a column
sales_data['Country'].unique()
# Out:
# array(['SwedeN', 'United kingdom', 'france', 'United Kingdom', 'FrancE',
#        'France', 'FrAnce', 'ITAly', 'Austria', 'Spain', 'Germany',
#        'Netherlands', 'SWEDEN', 'Denmark', 'Italy', 'Belgium', 'Norway',
#        'Portugal', 'Sweden', 'Switzerland', 'Ireland', 'Finland'],
#       dtype=object)

# %%
#replace values - Sweden
sales_data['Country']= sales_data['Country'].replace(['SwedeN', 'SWEDEN'], 'Sweden')
sales_data
# Out:
#              Order ID  Order Date  Year        Customer Name        City  \
# 0     BN-2011-7407039  01/01/2011  2011           Ruby Patel   Stockholm
# 1     AZ-2011-9050313  01/03/2011  2011       Summer Hayward   Southport
# 2     AZ-2011-6674300  01/04/2011  2011     Devin Huddleston     Valence
# 3     BN-2011-2819714  01/04/2011  2011          Mary Parker  Birmingham
# 4      AZ-2011-617423  01/05/2011  2011         Daniel Burke  EchirolleS
# ...               ...         ...   ...                  ...         ...
# 4112  AZ-2014-8174835  12/31/2014  2014         Eloise Sykes   Bielefeld
# 4113   AZ-2014-766953  12/31/2014  2014         Jose Gambino  Maidenhead
# 4114  AZ-2014-1412225  12/31/2014  2014          Leon Barnes   Worcester
# 4115  AZ-2014-7604524  12/31/2014  2014  Rebecca Chamberlain     Hamburg
# 4116  BN-2014-4140795  12/31/2014  2014      Daniel Hamilton   Eindhoven
#
#                        State         Country   Region      Segment     Sale  \
# ...

# %%
sales_data['Country'].unique()
# Out:
# array(['Sweden', 'United kingdom', 'france', 'United Kingdom', 'FrancE',
#        'France', 'FrAnce', 'ITAly', 'Austria', 'Spain', 'Germany',
#        'Netherlands', 'Denmark', 'Italy', 'Belgium', 'Norway', 'Portugal',
#        'Switzerland', 'Ireland', 'Finland'], dtype=object)

# %%
sales_data['Country']= sales_data['Country'].replace(['FrancE', 'FrAnce','france'], 'France')

# %%
sales_data['Country']= sales_data['Country'].replace(['United kingdom'], 'United Kingdom')

# %%
sales_data['Country']= sales_data['Country'].replace(['ITAly'], 'Italy')

# %%
sales_data['Country'].unique()
# Out:
# array(['Sweden', 'United Kingdom', 'France', 'Italy', 'Austria', 'Spain',
#        'Germany', 'Netherlands', 'Denmark', 'Belgium', 'Norway',
#        'Portugal', 'Switzerland', 'Ireland', 'Finland'], dtype=object)

# %%
numofcountries = len(sales_data['Country'].unique())
numofcountries
# Out:
# 15

# %%
numofCities = len(sales_data['City'].unique())
numofCities
# Out:
# 1005

# %%
sales_data['City'].unique()# as there are too mny to list the array shows ... to indicate the large size of the dataset
# Out:
# array(['Stockholm', 'Southport', 'Valence', ..., 'Arrentela',
#        'Clacton-on-Sea', 'Sagunto'], dtype=object)

# %%
sales_data.columns # this shows the column names in the table
# Out:
# Index(['Order ID', 'Order Date', 'Year', 'Customer Name', 'City', 'State',
#        'Country', 'Region', 'Segment', 'Sale', 'Item Cost', 'Unit Sold',
#        'item'],
#       dtype='object')

# %%
#create a new table using the column names
SaleDataItems=sales_data[['Order ID', 'item', 'Sale']]
SaleDataItems
# Out:
#              Order ID       item     Sale
# 0     BN-2011-7407039      Paper   $45.00
# 1     AZ-2011-9050313  Bookcases  $854.00
# 2     AZ-2011-6674300        Art  $140.00
# 3     BN-2011-2819714        Art   $27.00
# 4      AZ-2011-617423    Storage   $17.00
# ...               ...        ...      ...
# 4112  AZ-2014-8174835      Paper   $14.00
# 4113   AZ-2014-766953        Art   $52.00
# 4114  AZ-2014-1412225        Art  $100.00
# 4115  AZ-2014-7604524   Supplies  $136.00
# 4116  BN-2014-4140795     Phones  $132.00
#
# [4117 rows x 3 columns]

# %%
#rename columns
names = {'Order ID': 'Order_ID',
         'item': 'Item',
         'Sale' : 'Sales'}
SaleDataItems.rename(columns=names, inplace=True)
SaleDataItems
# Out:
# <ipython-input-38-d70a6c4d0bd1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SaleDataItems.rename(columns=names, inplace=True)
#              Order_ID       Item    Sales
# 0     BN-2011-7407039      Paper   $45.00
# 1     AZ-2011-9050313  Bookcases  $854.00
# 2     AZ-2011-6674300        Art  $140.00
# 3     BN-2011-2819714        Art   $27.00
# 4      AZ-2011-617423    Storage   $17.00
# ...               ...        ...      ...
# 4112  AZ-2014-8174835      Paper   $14.00
# 4113   AZ-2014-766953        Art   $52.00
# 4114  AZ-2014-1412225        Art  $100.00
# 4115  AZ-2014-7604524   Supplies  $136.00
# 4116  BN-2014-4140795     Phones  $132.00
#
# [4117 rows x 3 columns]

# %%
#create a location table with columns city state country and region
location = sales_data[['City', 'State', 'Country', 'Region']] # you can rearrange the order, dont have to have htem in original table order
location
# Out:
#             City                   State         Country   Region
# 0      Stockholm               Stockholm          Sweden    North
# 1      Southport                 England  United Kingdom    North
# 2        Valence    Auvergne-Rhône-Alpes          France  Central
# 3     Birmingham                 England  United Kingdom    North
# 4     EchirolleS    Auvergne-Rhône-Alpes          France  Central
# ...          ...                     ...             ...      ...
# 4112   Bielefeld  North Rhine-Westphalia         Germany  Central
# 4113  Maidenhead                 England  United Kingdom    North
# 4114   Worcester                 England  United Kingdom    North
# 4115     Hamburg                 Hamburg         Germany  Central
# 4116   Eindhoven           North Brabant     Netherlands  Central
#
# [4117 rows x 4 columns]

# %%
SaleDataItems
# Out:
#              Order_ID       Item    Sales
# 0     BN-2011-7407039      Paper   $45.00
# 1     AZ-2011-9050313  Bookcases  $854.00
# 2     AZ-2011-6674300        Art  $140.00
# 3     BN-2011-2819714        Art   $27.00
# 4      AZ-2011-617423    Storage   $17.00
# ...               ...        ...      ...
# 4112  AZ-2014-8174835      Paper   $14.00
# 4113   AZ-2014-766953        Art   $52.00
# 4114  AZ-2014-1412225        Art  $100.00
# 4115  AZ-2014-7604524   Supplies  $136.00
# 4116  BN-2014-4140795     Phones  $132.00
#
# [4117 rows x 3 columns]

# %%
SaleDataItems.loc[3] = {'Order_ID':'Order01',
                        'Item':'Desk',
                        'Sales':'$70'}
SaleDataItems
# Out:
#              Order_ID       Item    Sales
# 0     BN-2011-7407039      Paper   $45.00
# 1     AZ-2011-9050313  Bookcases  $854.00
# 2     AZ-2011-6674300        Art  $140.00
# 3             Order01       Desk      $70
# 4      AZ-2011-617423    Storage   $17.00
# ...               ...        ...      ...
# 4112  AZ-2014-8174835      Paper   $14.00
# 4113   AZ-2014-766953        Art   $52.00
# 4114  AZ-2014-1412225        Art  $100.00
# 4115  AZ-2014-7604524   Supplies  $136.00
# 4116  BN-2014-4140795     Phones  $132.00
#
# [4117 rows x 3 columns]

# %%
SaleDataItems.loc[4116] = {'Order_ID':'Order037', #changing the data in the columns in this object
                        'Item':'Nokia Phone',
                        'Sales':'$130'}
SaleDataItems
# Out:
#              Order_ID         Item    Sales
# 0     BN-2011-7407039        Paper   $45.00
# 1     AZ-2011-9050313    Bookcases  $854.00
# 2     AZ-2011-6674300          Art  $140.00
# 3             Order01         Desk      $70
# 4      AZ-2011-617423      Storage   $17.00
# ...               ...          ...      ...
# 4112  AZ-2014-8174835        Paper   $14.00
# 4113   AZ-2014-766953          Art   $52.00
# 4114  AZ-2014-1412225          Art  $100.00
# 4115  AZ-2014-7604524     Supplies  $136.00
# 4116         Order037  Nokia Phone     $130
#
# [4117 rows x 3 columns]

# %%
SaleDataItems.loc[SaleDataItems['Item'] == 'Desk']
# Out:
#   Order_ID  Item Sales
# 3  Order01  Desk   $70
